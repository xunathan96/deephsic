# %%
import sys
sys.path.append('..')

import numpy as np
import torch
from tqdm import tqdm

# %matplotlib inline
import matplotlib.pyplot as plt

from torchvision.datasets import CIFAR10

# %%
probs = np.load('../data/cifar10h/raw/cifar10h-probs.npy')
cifar = CIFAR10('data/cifar10h/raw', train=True, download=True)
# Out:
# Files already downloaded and verified

# %%
cifar.data[0].shape # (32,32,3)

cifar.targets[0]

len(cifar)
# Out:
# 50000

# %%
probs[0]
# Out:
# array([0.        , 0.01960784, 0.01960784, 0.94117647, 0.        ,
#        0.01960784, 0.        , 0.        , 0.        , 0.        ])

# %%
from data.cifar10h.cifar10h import CIFAR10H

# %%
cifar10h = CIFAR10H('../data/cifar10h/raw', download=True)
# Out:
# Files already downloaded and verified

# %%
cifar10h[3229]
# Out:
# (<PIL.Image.Image image mode=RGB size=32x32>,
#  9,
#  array([0.        , 0.03921569, 0.        , 0.        , 0.        ,
#         0.        , 0.        , 0.        , 0.        , 0.96078431]))
