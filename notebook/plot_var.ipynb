# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')

import glob
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None
# https://stackoverflow.com/questions/20625582/how-to-deal-with-settingwithcopywarning-in-pandas
from pathlib import Path
from tqdm import tqdm
import re

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
METHOD = "hsic"
DATASET = "hdgm10"
SAMPLE_SIZE = 1024
WINDOW = 988

epochs = np.arange(WINDOW)
vars_hsic = np.load(f"../src/exp/eval/hdgm/variance_tests/hsic-var-{DATASET}-{SAMPLE_SIZE}.npy")[:WINDOW]
vars_mmd = np.load(f"../src/exp/eval/hdgm/variance_tests/mmd-var-{DATASET}-{SAMPLE_SIZE}.npy")[:WINDOW]
vars_mmd_split = np.load(f"../src/exp/eval/hdgm/variance_tests/mmd-split-var-{DATASET}-{SAMPLE_SIZE}.npy")[:WINDOW]

plt.plot(epochs, vars_hsic, label='hsic')
plt.plot(epochs, vars_mmd, label='mmd-full')
plt.plot(epochs, vars_mmd_split, label='mmd-split')
plt.legend(prop={'size': 16})

plt.grid()
plt.xlabel("epochs", fontsize=24)
plt.ylabel("variance", fontsize=24)

plt.rcParams['axes.linewidth'] = 0.2
plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.tick_params(left=False,) # labelsize=18)
plt.tick_params(bottom=False,) # labelsize=18)
# plt.gca().xaxis.set_major_locator(plt.MultipleLocator(1000))
# plt.savefig(f"plots/variance/variance-split-{DATASET}-{SAMPLE_SIZE}.pdf", format="pdf", bbox_inches="tight")
