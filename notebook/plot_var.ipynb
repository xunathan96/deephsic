# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')

import glob
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None
# https://stackoverflow.com/questions/20625582/how-to-deal-with-settingwithcopywarning-in-pandas
from pathlib import Path
from tqdm import tqdm
import re

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
METHOD = "hsic"
DATASET = "hdgm30"
SAMPLE_SIZE = 1024
WINDOW = 300

epochs = np.arange(WINDOW)
vars_hsic = np.load(f"../src/exp/eval/vars/hsic-var-{DATASET}-{SAMPLE_SIZE}.npy")[:WINDOW]
vars_mmd = np.load(f"../src/exp/eval/vars/mmd-var-{DATASET}-{SAMPLE_SIZE}.npy")[:WINDOW]

plt.plot(epochs, vars_hsic, label='hsic')
plt.plot(epochs, vars_mmd, label='mmd')
plt.legend(prop={'size': 16})

plt.grid()
plt.xlabel("epochs", fontsize=24)
plt.ylabel("variance", fontsize=24)

plt.rcParams['axes.linewidth'] = 0.2
# plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.tick_params(left=False,) # labelsize=18)
plt.tick_params(bottom=False,) # labelsize=18)
# plt.gca().xaxis.set_major_locator(plt.MultipleLocator(1000))
plt.savefig(f"plots/variance/variance-{METHOD}-{DATASET}-{SAMPLE_SIZE}.pdf", format="pdf", bbox_inches="tight")
# Out:
# hsic_var_0: 1.9845734248701717e-08
# hsic_var_1: 8.682996652317583e-06
# mmd_var_0: 8.130459461278165e-06
# mmd_var_1: 0.0002893553360731208
#   Cell In[47], line 18
#     return
#     ^
# SyntaxError: 'return' outside function
